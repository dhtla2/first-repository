# %% [markdown]
# # 1. 필요한 라이브러리 import 및 데이터 확인

# %%
import glob
import os, re
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

txt_file_path = os.getenv('HOME')+'/aiffel/lyricist/data/lyrics/*'

txt_list = glob.glob(txt_file_path)

raw_corpus = []

# 여러개의 txt 파일을 모두 읽어서 raw_corpus 에 담습니다.
for txt_file in txt_list:
    with open(txt_file, "r") as f:
        raw = f.read().splitlines()
        raw_corpus.extend(raw)

print("데이터 크기:", len(raw_corpus))
print("Examples:\n", raw_corpus[:10])
# Out:
# 데이터 크기: 187088
# Examples:
#  [' There must be some kind of way outta here', 'Said the joker to the thief', "There's too much confusion", "I can't get no relief Business men, they drink my wine", 'Plowman dig my earth', 'None were level on the mind', 'Nobody up at his word', 'Hey, hey No reason to get excited', 'The thief he kindly spoke', 'There are many here among us']

# %% [markdown]
# # 2. 문장 정제

# %%
# 입력된 문장을
#     1. 소문자로 바꾸고, 양쪽 공백을 지웁니다
#     2. 특수문자 양쪽에 공백을 넣고
#     3. 여러개의 공백은 하나의 공백으로 바꿉니다
#     4. a-zA-Z?.!,¿가 아닌 모든 문자를 하나의 공백으로 바꿉니다
#     5. 다시 양쪽 공백을 지웁니다
#     6. 문장 시작에는 <start>, 끝에는 <end>를 추가합니다
# 이 순서로 처리해주면 문제가 되는 상황을 방지할 수 있겠네요!
def preprocess_sentence(sentence):
    sentence = sentence.lower().strip() # 1
    sentence = re.sub(r"([?.!,¿])", r" \1 ", sentence) # 2
    sentence = re.sub(r'[" "]+', " ", sentence) # 3
    sentence = re.sub(r"[^a-zA-Z?.!,¿]+", " ", sentence) # 4
    sentence = sentence.strip() # 5
    if len(sentence) == 0 :
        return 0
    elif sentence.count(" ") > 12:
        return 0
    else:
        sentence = '<start> ' + sentence + ' <end>' # 6
        return sentence

# 이 문장이 어떻게 필터링되는지 확인해 보세요.
print(preprocess_sentence("This @_is ;;;sample        sentence."))
# Out:
# <start> this is sample sentence . <end>

# %% [markdown]
# ## 함수를 만들때, 팀원의 도움을 받았습니다.
# ### 처음에 제가 만들때는 함수를 만들고 뒤에가서 걸러 내려고 했는데, 함수를 짜면서 원하지 않는 문장을 바로 0으로 리턴해 그 다음에 필요한 문장만 뽑는다면 메모리와 처리 속도를 올릴 수 있어 필요한 문장을 뽑는 함수를 만들었습니다.

# %% [markdown]
# # 3. 정제된 문장을 모으고 일부 출력해보겠습니다.

# %%
# 여기에 정제된 문장을 모을겁니다
corpus = []

for sentence in raw_corpus:
    preprocessed_sentence = preprocess_sentence(sentence)
    if preprocessed_sentence == 0:
        pass
    else:
        corpus.append(preprocessed_sentence)
        
# 정제된 결과를 10개만 확인해보죠
corpus[:10]
# Out:
# ['<start> there must be some kind of way outta here <end>',
#  '<start> said the joker to the thief <end>',
#  '<start> there s too much confusion <end>',
#  '<start> i can t get no relief business men , they drink my wine <end>',
#  '<start> plowman dig my earth <end>',
#  '<start> none were level on the mind <end>',
#  '<start> nobody up at his word <end>',
#  '<start> hey , hey no reason to get excited <end>',
#  '<start> the thief he kindly spoke <end>',
#  '<start> there are many here among us <end>']

# %% [markdown]
# # 4. 토크나이저 생성

# %%
# 토큰화 할 때 텐서플로우의 Tokenizer와 pad_sequences를 사용합니다
# 더 잘 알기 위해 아래 문서들을 참고하면 좋습니다
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/text/Tokenizer
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/sequence/pad_sequences
def tokenize(corpus):
    # 12000단어를 기억할 수 있는 tokenizer를 만들겁니다
    # 우리는 이미 문장을 정제했으니 filters가 필요없어요
    # 12000단어에 포함되지 못한 단어는 '<unk>'로 바꿀거에요
    tokenizer = tf.keras.preprocessing.text.Tokenizer(
        num_words=12000, 
        filters=' ',
        oov_token="<unk>"
    )
    # corpus를 이용해 tokenizer 내부의 단어장을 완성합니다
    tokenizer.fit_on_texts(corpus)
    # 준비한 tokenizer를 이용해 corpus를 Tensor로 변환합니다
    tensor = tokenizer.texts_to_sequences(corpus)   
    # 입력 데이터의 시퀀스 길이를 일정하게 맞춰줍니다
    # 만약 시퀀스가 짧다면 문장 뒤에 패딩을 붙여 길이를 맞춰줍니다.
    # 문장 앞에 패딩을 붙여 길이를 맞추고 싶다면 padding='pre'를 사용합니다
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post', maxlen=15)  
    print(tensor,tokenizer)
    return tensor, tokenizer

tensor, tokenizer = tokenize(corpus)
# Out:
# [[  2  62 271 ...   0   0   0]
#  [  2 117   6 ...   0   0   0]
#  [  2  62  17 ...   0   0   0]
#  ...
#  [  2  75  45 ...   3   0   0]
#  [  2  49   5 ...   0   0   0]
#  [  2  13 635 ...   0   0   0]] <keras_preprocessing.text.Tokenizer object at 0x7f97d07d1490>

# %% [markdown]
# ## 여러 옵션들을 텐서플로우 튜토리얼에서 확인했습니다.

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/84653776/135948844-6df468fc-a50c-427a-88da-20466a1f0b16.png)

# %% [markdown]
# ## 문장이 잘 바뀌었나 확인해 보겠습니다.

# %%
print(tensor[:3, :10])
# Out:
# [[   2   62  271   27   94  546   20   86  743   90]
#  [   2  117    6 6269   10    6 2310    3    0    0]
#  [   2   62   17  102  184 2718    3    0    0    0]]

# %% [markdown]
# ## 생성된 단어장을 확인해 보겠습니다.

# %%
for idx in tokenizer.index_word:
    print(idx, ":", tokenizer.index_word[idx])

    if idx >= 10: break
# Out:
# 1 : <unk>
# 2 : <start>
# 3 : <end>
# 4 : i
# 5 : ,
# 6 : the
# 7 : you
# 8 : and
# 9 : a
# 10 : to

# %% [markdown]
# ### 단어장을 생성해 보았는데 여러번 돌려도 같은 순서같고, 12000단어의 중요도를 어떻게 판단하는지 궁금했는데 수요일 TF 마스터 수업에서 조원의 도움으로 알게되었다.

# %%
config = tokenizer.get_config()
print(config)
# Out:
# {'num_words': 12000, 'filters': ' ', 'lower': True, 'split': ' ', 'char_level': False, 'oov_token': '<unk>', 'document_count': 156174, 'word_counts': '{"<start>": 156174, "there": 3040, "must": 509, "be": 6646, "some": 1847, "kind": 224, "of": 8964, "way": 2081, "outta": 145, "here": 1914, "<end>": 156174, "said": 1485, "the": 39314, "joker": 7, "to": 20368, "thief": 31, "s": 11126, "too": 1681, "much": 818, "confusion": 25, "i": 45489, "can": 5616, "t": 11207, "get": 4928, "no": 5083, "relief": 8, "business": 136, "men": 184, ",": 43415, "they": 5200, "drink": 264, "my": 15171, "wine": 106, "plowman": 1, "dig": 88, "earth": 180, "none": 102, "were": 912, "level": 45, "on": 9773, "mind": 871, "nobody": 588, "up": 6341, "at": 2758, "his": 1750, "word": 257, "hey": 1145, "reason": 210, "excited": 28, "he": 3802, "kindly": 12, "spoke": 47, "are": 2515, "many": 433, "among": 37, "us": 1353, "who": 1867, "feel": 1619, "that": 11539, "life": 1595, "is": 7287, "but": 5695, "a": 20617, "joke": 42, "and": 23103, "this": 5083, "not": 2793, "our": 1113, "fate": 70, "so": 5964, "let": 2816, "stop": 983, "talkin": 276, "falsely": 3, "now": 3965, "hour": 119, "getting": 361, "late": 307, "all": 7435, "along": 200, "watchtower": 2, "princes": 2, "kept": 88, "view": 44, "while": 615, "women": 214, "came": 593, "went": 488, "barefoot": 7, "servants": 5, "outside": 138, "in": 13187, "cold": 388, "distance": 72, "wildcat": 3, "did": 903, "growl": 5, "two": 673, "riders": 11, "approaching": 5, "wind": 200, "began": 65, "howl": 8, "intro": 30, "joe": 45, "where": 1750, "you": 34759, "going": 743, "with": 6257, "gun": 231, "your": 9028, "hand": 625, "?": 4686, "verse": 261, "m": 7479, "down": 3457, "shoot": 154, "old": 743, "lady": 257, "know": 5643, "caught": 188, "her": 2870, "messing": 34, "around": 1258, "another": 766, "man": 2166, "ain": 1805, "cool": 246, "heard": 432, "shot": 330, "woman": 324, "ground": 218, "yes": 555, "town": 354, "gave": 299, "!": 3317, "guitar": 51, "solo": 30, "bridge": 131, "alright": 484, "one": 3349, "more": 1772, "time": 2526, "baby": 3837, "run": 529, "go": 3792, "well": 1059, "it": 16525, "south": 102, "mexico": 21, "free": 520, "find": 737, "me": 15874, "hangman": 1, "gonna": 1700, "put": 1136, "rope": 36, "better": 1105, "believe": 662, "right": 2077, "got": 5348, "outro": 31, "goodbye": 129, "everybody": 906, "ow": 67, "uh": 618, "purple": 95, "haze": 18, "brain": 164, "lately": 47, "things": 911, "don": 5140, "seem": 178, "same": 515, "actin": 57, "funny": 122, "why": 1466, "excuse": 63, "kiss": 353, "sky": 532, "if": 3868, "comin": 237, "or": 1607, "am": 1070, "happy": 337, "misery": 35, "help": 424, "oh": 4619, "ooo": 38, "ahhh": 16, "yeah": 4037, "eyes": 785, "day": 1454, "night": 1511, "blowin": 56, "tomorrow": 195, "just": 5724, "end": 410, "ahh": 60, "yea": 162, "tell": 1779, "like": 7721, "re": 3708, "makin": 141, "blow": 351, "n": 258, "nooo": 5, "foxy": 26, "cute": 56, "little": 1517, "heartbreaker": 9, "sweet": 376, "lovemaker": 2, "wanna": 2009, "take": 2269, "home": 984, "won": 886, "do": 4530, "harm": 31, "ve": 1831, "mine": 587, "make": 2716, "scream": 161, "ah": 511, "listen": 260, "made": 657, "tired": 175, "wasting": 25, "precious": 45, "come": 2807, "ya": 1388, "look": 1271, "good": 1500, "give": 1506, "babe": 301, "sayin": 181, "after": 360, "jacks": 7, "their": 637, "boxes": 10, "clowns": 9, "have": 2544, "gone": 785, "bed": 338, "hear": 812, "happiness": 83, "staggering": 2, "street": 243, "footprints": 7, "dressed": 71, "red": 291, "whispers": 15, "mary": 113, "broom": 20, "drearily": 1, "sweeping": 12, "broken": 251, "pieces": 65, "yesterdays": 1, "somewhere": 135, "queen": 143, "weeping": 20, "king": 248, "has": 529, "wife": 122, "shine": 228, "emptiness": 13, "tiny": 17, "island": 51, "sags": 2, "downstream": 2, "cause": 2844, "lived": 73, "dead": 329, "screams": 24, "will": 2222, "ever": 979, "remember": 433, "names": 72, "blown": 32, "past": 231, "crutch": 2, "its": 1283, "age": 44 ...

# %% [markdown]
# ### get_config 란 메소드를 통해서 토크나이저의 여러 정보를 불러왔다. <br/> 그 안에 word_counts 라는 딕셔너리가 보였다.
#
# ### 그래서 word_counts 딕셔너리만 불러와 보았다.

# %%
config_word = config['word_counts']

# %% [markdown]
# ### 단어장에 쓰인 단어와 그 순서가 딕셔너리 구조로 저장되어있는 것을 확인했다.

# %%
print(config_word)
# Out:
# {"<start>": 156174, "there": 3040, "must": 509, "be": 6646, "some": 1847, "kind": 224, "of": 8964, "way": 2081, "outta": 145, "here": 1914, "<end>": 156174, "said": 1485, "the": 39314, "joker": 7, "to": 20368, "thief": 31, "s": 11126, "too": 1681, "much": 818, "confusion": 25, "i": 45489, "can": 5616, "t": 11207, "get": 4928, "no": 5083, "relief": 8, "business": 136, "men": 184, ",": 43415, "they": 5200, "drink": 264, "my": 15171, "wine": 106, "plowman": 1, "dig": 88, "earth": 180, "none": 102, "were": 912, "level": 45, "on": 9773, "mind": 871, "nobody": 588, "up": 6341, "at": 2758, "his": 1750, "word": 257, "hey": 1145, "reason": 210, "excited": 28, "he": 3802, "kindly": 12, "spoke": 47, "are": 2515, "many": 433, "among": 37, "us": 1353, "who": 1867, "feel": 1619, "that": 11539, "life": 1595, "is": 7287, "but": 5695, "a": 20617, "joke": 42, "and": 23103, "this": 5083, "not": 2793, "our": 1113, "fate": 70, "so": 5964, "let": 2816, "stop": 983, "talkin": 276, "falsely": 3, "now": 3965, "hour": 119, "getting": 361, "late": 307, "all": 7435, "along": 200, "watchtower": 2, "princes": 2, "kept": 88, "view": 44, "while": 615, "women": 214, "came": 593, "went": 488, "barefoot": 7, "servants": 5, "outside": 138, "in": 13187, "cold": 388, "distance": 72, "wildcat": 3, "did": 903, "growl": 5, "two": 673, "riders": 11, "approaching": 5, "wind": 200, "began": 65, "howl": 8, "intro": 30, "joe": 45, "where": 1750, "you": 34759, "going": 743, "with": 6257, "gun": 231, "your": 9028, "hand": 625, "?": 4686, "verse": 261, "m": 7479, "down": 3457, "shoot": 154, "old": 743, "lady": 257, "know": 5643, "caught": 188, "her": 2870, "messing": 34, "around": 1258, "another": 766, "man": 2166, "ain": 1805, "cool": 246, "heard": 432, "shot": 330, "woman": 324, "ground": 218, "yes": 555, "town": 354, "gave": 299, "!": 3317, "guitar": 51, "solo": 30, "bridge": 131, "alright": 484, "one": 3349, "more": 1772, "time": 2526, "baby": 3837, "run": 529, "go": 3792, "well": 1059, "it": 16525, "south": 102, "mexico": 21, "free": 520, "find": 737, "me": 15874, "hangman": 1, "gonna": 1700, "put": 1136, "rope": 36, "better": 1105, "believe": 662, "right": 2077, "got": 5348, "outro": 31, "goodbye": 129, "everybody": 906, "ow": 67, "uh": 618, "purple": 95, "haze": 18, "brain": 164, "lately": 47, "things": 911, "don": 5140, "seem": 178, "same": 515, "actin": 57, "funny": 122, "why": 1466, "excuse": 63, "kiss": 353, "sky": 532, "if": 3868, "comin": 237, "or": 1607, "am": 1070, "happy": 337, "misery": 35, "help": 424, "oh": 4619, "ooo": 38, "ahhh": 16, "yeah": 4037, "eyes": 785, "day": 1454, "night": 1511, "blowin": 56, "tomorrow": 195, "just": 5724, "end": 410, "ahh": 60, "yea": 162, "tell": 1779, "like": 7721, "re": 3708, "makin": 141, "blow": 351, "n": 258, "nooo": 5, "foxy": 26, "cute": 56, "little": 1517, "heartbreaker": 9, "sweet": 376, "lovemaker": 2, "wanna": 2009, "take": 2269, "home": 984, "won": 886, "do": 4530, "harm": 31, "ve": 1831, "mine": 587, "make": 2716, "scream": 161, "ah": 511, "listen": 260, "made": 657, "tired": 175, "wasting": 25, "precious": 45, "come": 2807, "ya": 1388, "look": 1271, "good": 1500, "give": 1506, "babe": 301, "sayin": 181, "after": 360, "jacks": 7, "their": 637, "boxes": 10, "clowns": 9, "have": 2544, "gone": 785, "bed": 338, "hear": 812, "happiness": 83, "staggering": 2, "street": 243, "footprints": 7, "dressed": 71, "red": 291, "whispers": 15, "mary": 113, "broom": 20, "drearily": 1, "sweeping": 12, "broken": 251, "pieces": 65, "yesterdays": 1, "somewhere": 135, "queen": 143, "weeping": 20, "king": 248, "has": 529, "wife": 122, "shine": 228, "emptiness": 13, "tiny": 17, "island": 51, "sags": 2, "downstream": 2, "cause": 2844, "lived": 73, "dead": 329, "screams": 24, "will": 2222, "ever": 979, "remember": 433, "names": 72, "blown": 32, "past": 231, "crutch": 2, "its": 1283, "age": 44, "wisdom": 27, "last": 633, "cries": 22, "wild": 273, "thing": 825, "heart": 1234, "sing": 428, "everything": 903, "groovy": 27, "think": 1291, "love" ...

# %% [markdown]
# ### 밸류값 순서로 정렬해 보았다.

# %%
sorted(config_word.items(), key=lambda x : x[1], reverse=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-4e3ab92a5f3c> in <module>
# ----> 1 sorted(config_word.items(), key=lambda x : x[1], reverse=True)
#
# AttributeError: 'str' object has no attribute 'items'

# %% [markdown]
# ### 에러가 발생했고, dict 타입이 아니라 str 타입이라는것 같다.
#
# ### 혹시 몰라 타입을 조회해 보았다.

# %%
type(config_word)
# Out:
# str

# %% [markdown]
# ### dict 구조의 str이라는것을 확인했다.
#
# ### 그래서 이러한 str을 dict으로 바꿔주는 함수가 있어 적용해 보았다.

# %%
config_word_d = eval(config_word)

# %%
type(config_word_d)
# Out:
# dict

# %% [markdown]
# ### dict으로 잘 변경되었다.

# %%
sorted(config_word_d.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('<start>', 156174),
#  ('<end>', 156174),
#  ('i', 45489),
#  (',', 43415),
#  ('the', 39314),
#  ('you', 34759),
#  ('and', 23103),
#  ('a', 20617),
#  ('to', 20368),
#  ('it', 16525),
#  ('me', 15874),
#  ('my', 15171),
#  ('in', 13187),
#  ('that', 11539),
#  ('t', 11207),
#  ('s', 11126),
#  ('on', 9773),
#  ('your', 9028),
#  ('of', 8964),
#  ('we', 8493),
#  ('.', 8136),
#  ('like', 7721),
#  ('m', 7479),
#  ('all', 7435),
#  ('is', 7287),
#  ('be', 6646),
#  ('for', 6410),
#  ('up', 6341),
#  ('with', 6257),
#  ('so', 5964),
#  ('just', 5724),
#  ('but', 5695),
#  ('know', 5643),
#  ('can', 5616),
#  ('love', 5380),
#  ('got', 5348),
#  ('they', 5200),
#  ('what', 5188),
#  ('don', 5140),
#  ('no', 5083),
#  ('this', 5083),
#  ('get', 4928),
#  ('she', 4808),
#  ('when', 4718),
#  ('?', 4686),
#  ('oh', 4619),
#  ('do', 4530),
#  ('yeah', 4037),
#  ('now', 3965),
#  ('if', 3868),
#  ('baby', 3837),
#  ('was', 3825),
#  ('he', 3802),
#  ('go', 3792),
#  ('re', 3708),
#  ('out', 3677),
#  ('down', 3457),
#  ('one', 3349),
#  ('!', 3317),
#  ('ll', 3043),
#  ('there', 3040),
#  ('see', 2929),
#  ('want', 2912),
#  ('her', 2870),
#  ('cause', 2844),
#  ('let', 2816),
#  ('come', 2807),
#  ('not', 2793),
#  ('at', 2758),
#  ('say', 2735),
#  ('make', 2716),
#  ('from', 2621),
#  ('have', 2544),
#  ('back', 2538),
#  ('time', 2526),
#  ('are', 2515),
#  ('im', 2488),
#  ('how', 2430),
#  ('never', 2380),
#  ('as', 2305),
#  ('girl', 2279),
#  ('take', 2269),
#  ('will', 2222),
#  ('man', 2166),
#  ('way', 2081),
#  ('right', 2077),
#  ('u', 2017),
#  ('wanna', 2009),
#  ('here', 1914),
#  ('then', 1888),
#  ('need', 1882),
#  ('who', 1867),
#  ('some', 1847),
#  ('ve', 1831),
#  ('ain', 1805),
#  ('tell', 1779),
#  ('more', 1772),
#  ('his', 1750),
#  ('where', 1750),
#  ('gonna', 1700),
#  ('too', 1681),
#  ('them', 1676),
#  ('could', 1662),
#  ('been', 1625),
#  ('feel', 1619),
#  ('or', 1607),
#  ('life', 1595),
#  ('shit', 1539),
#  ('had', 1533),
#  ('little', 1517),
#  ('about', 1515),
#  ('night', 1511),
#  ('give', 1506),
#  ('good', 1500),
#  ('by', 1500),
#  ('said', 1485),
#  ('off', 1479),
#  ('why', 1466),
#  ('day', 1454),
#  ('keep', 1399),
#  ('only', 1395),
#  ('ya', 1388),
#  ('every', 1380),
#  ('still', 1364),
#  ('us', 1353),
#  ('through', 1342),
#  ('em', 1342),
#  ('bitch', 1299),
#  ('think', 1291),
#  ('these', 1288),
#  ('its', 1283),
#  ('look', 1271),
#  ('would', 1270),
#  ('fuck', 1269),
#  ('around', 1258),
#  ('dont', 1252),
#  ('away', 1236),
#  ('heart', 1234),
#  ('money', 1220),
#  ('d', 1216),
#  ('over', 1185),
#  ('world', 1183),
#  ('him', 1164),
#  ('an', 1146),
#  ('hey', 1145),
#  ('put', 1136),
#  ('gotta', 1136),
#  ('our', 1113),
#  ('better', 1105),
#  ('call', 1076),
#  ('am', 1070),
#  ('new', 1061),
#  ('aint', 1060),
#  ('well', 1059),
#  ('boy', 1054),
#  ('bad', 1037),
#  ('even', 1024),
#  ('home', 984),
#  ('stop', 983),
#  ('ever', 979),
#  ('la', 977),
#  ('nigga', 971),
#  ('really', 960),
#  ('big', 956),
#  ('than', 952),
#  ('niggas', 935),
#  ('long', 933),
#  ('always', 925),
#  ('nothing', 919),
#  ('people', 913),
#  ('were', 912),
#  ('things', 911),
#  ('before', 911),
#  ('everybody', 906),
#  ('did', 903),
#  ('everything', 903),
#  ('won', 886),
#  ('again', 876),
#  ('head', 874),
#  ('mind', 871),
#  ('hold', 845),
#  ('thing', 825),
#  ('much', 818),
#  ('show', 815),
#  ('hear', 812),
#  ('god', 812),
#  ('da', 809),
#  ('should', 798),
#  ('ooh', 795),
#  ('name', 789),
#  ('eyes', 785),
#  ('gone', 785),
#  ('live', 785),
#  ('leave', 785),
#  ('ass', 783),
#  ('something', 771),
#  ('another', 766),
#  ('hit', 764),
#  ('hard', 760),
#  ('turn', 756),
#  ('face', 753),
#  ('yo', 752),
#  ('going', 743),
#  ('old', 743),
#  ('find', 737),
#  ('real', 737),
#  ('talk', 727),
#  ('try', 719),
#  ('play', 717),
#  ('light', 706),
#  ('high', 702),
#  ('nixga', 694),
#  ('body', 691),
#  ('alone', 674),
#  ('two', 673),
#  ('stay', 664),
#  ('believe', 662),
#  ('made', 657),
#  ('into', 652),
#  ('dance', 652),
#  ('thats', 648),
#  ('their', 637),
#  ('told', 636),
#  ('last', 633),
#  ('please', 627),
#  ('hand', 625),
#  ('tonight', 625),
#  ('uh', 618),
#  ('while', 615),
#  ('other', 614),
#  ('bout', 610),
#  ('hot', 604),
#  ('work', 600),
#  ('best', 600),
#  ('came', 593),
#  ('nobody', 588),
#  ('mine', 587),
#  ('na', 586),
#  ('round', 583),
#  ('gon', 583),
#  ('left', 580),
#  ('black', 580),
#  ('chorus', 573),
#  ('die', 570),
#  ('bitches', 566),
#  ('whole', 557),
#  ('first', 557),
#  ('somebody', 557),
#  ('place', 557),
#  ('yes', 555),
#  ('mean', 550),
#  ('cant', 547),
#  ('fly', 544),
#  ('young', 543),
#  ('enough', 542),
#  ('without', 535),
#  ('girls', 534),
#  ('sky', 532),
#  ('stand', 532),
#  ('wait', 531),
#  ('run', 529),
#  ('has', 529),
#  ('hands', 526),
#  ('done', 523),
#  ('free', 520),
#  ('thought', 519),
#  ('same', 515),
#  ('cry', 514),
#  ('ah', 511),
#  ('must', 509),
#  ('damn', 508),
#  ('crazy', 505),
#  ('friends', 505),
#  ('wish', 503),
#  ('together', 502),
#  ('wrong', 501),
#  ('inside', 496),
#  ('went', 488),
#  ('goin', 488),
#  ('alright', 484),
#  ('game', 476),
#  ('own', 472),
#  ('coming', 470),
#  ('used', 466),
#  ('sun', 464),
#  ('fire', 463),
#  ('care', 460),
#  ('rock', 456),
#  ('party', 455),
#  ('looking', 454),
#  ('til', 451),
#  ('fall', 448),
#  ('maybe', 448),
#  ('ready', 446),
#  ('whoa', 445),
#  ('break', 444),
#  ('friend', 441),
#  ('might', 436),
#  ('soul', 434),
#  ('many', 433),
#  ('remember', 433),
#  ('heard', 432),
#  ('watch', 429),
#  ('sing', 428),
#  ('move', 428),
#  ('seen', 428),
#  ('ask', 426),
#  ('touch', 426),
#  ('bring', 425),
#  ('help', 424),
#  ('side', 423),
#  ('fuckin', 421),
#  ('door', 419),
#  ('trying', 419),
#  ('knows', 418),
#  ('ride', 418),
#  ('though', 418),
#  ('lost', 417),
#  ('white', 416),
#  ('myself', 416),
#  ('because', 415),
#  ('house', 413),
#  ('till', 413),
#  ('end', 410),
#  ('guess', 410),
#  ('someone', 408),
#  ('forever', 408),
#  ('wit', 408),
#  ('next', 406),
#  ('pussy', 406),
#  ('change', 403),
#  ('music', 399),
#  ('took', 397),
#  ('walk', 395),
#  ('goes', 394),
#  ('feeling', 393),
#  ('mama', 390),
#  ('true', 390),
#  ('cold', 388),
#  ('lie', 388),
#  ('nixgas', 386),
#  ('beat', 385),
#  ('start', 384),
#  ('y', 384),
#  ('yall', 383),
#  ('days', 381),
#  ('morning', 379),
#  ('may', 378),
#  ('sweet', 376),
#  ('matter', 373),
#  ('far', 371),
#  ('huh', 371),
#  ('hope', 370),
#  ('biggie', 370),
#  ('floor', 369),
#  ('song', 367),
#  ('getting', 361),
#  ('blue', 361),
#  ('after', 360),
#  ('dream', 360),
#  ('rain', 360),
#  ('knew', 360),
#  ('any', 358),
#  ('top', 358),
#  ('room', 357),
#  ('sometimes', 355),
#  ('town', 354),
#  ('kiss', 353),
#  ('waiting', 353),
#  ('blow', 351),
#  ('until', 348),
#  ('miss', 348),
#  ('lord', 347),
#  ('dreams', 345),
#  ('didn', 343),
#  ('daddy', 343),
#  ('smile', 342),
#  ('those', 341),
#  ('beautiful', 341),
#  ('ma', 341),
#  ('lights', 340),
#  ('pretty', 340),
#  ('since', 339),
#  ('bed', 338),
#  ('happy', 337),
#  ('gettin', 335),
#  ('drop', 333),
#  ('each', 333),
#  ('hate', 332),
#  ('dick', 331),
#  ('shot', 330),
#  ('dead', 329),
#  ('deep', 329),
#  ('under', 329),
#  ('once', 328),
#  ('ill', 328),
#  ('comes', 327),
#  ('throw', 326),
#  ('hair', 325),
#  ('three', 325),
#  ('woman', 324),
#  ('lose', 323),
#  ('hoes', 323),
#  ('lay', 321),
#  ('heaven', 320),
#  ('close', 320),
#  ('honey', 318),
#  ('times', 317),
#  ('alive', 317),
#  ('pain', 315),
#  ('boys', 313),
#  ('city', 313),
#  ('fight', 311),
#  ('cut', 309),
#  ('shake', 309),
#  ('full', 309),
#  ('roll', 309),
#  ('low', 309),
#  ('hurt', 308),
#  ('late', 307),
#  ('understand', 305),
#  ('gimme', 304),
#  ('nasty', 304),
#  ('living', 303),
#  ('hell', 303),
#  ('slow', 303),
#  ('straight', 302),
#  ('babe', 301),
#  ('fucking', 301),
#  ('talking', 300),
#  ('gave', 299),
#  ('years', 297),
#  ('sure', 295),
#  ('words', 295),
#  ('road', 295),
#  ('phone', 295),
#  ('car', 295),
#  ('pull', 294),
#  ('easy', 293),
#  ('forget', 293),
#  ('line', 292),
#  ('lot', 292),
#  ('club', 292),
#  ('red', 291),
#  ('sleep', 291),
#  ('check', 290),
#  ('streets', 289),
#  ('eat', 289),
#  ('arms', 286),
#  ('behind', 286),
#  ('dark', 285),
#  ('feet', 283),
#  ('pay', 283),
#  ('yourself', 283),
#  ('o', 281),
#  ('lookin', 280),
#  ('anything', 277),
#  ('talkin', 276),
#  ('lonely', 276),
#  ('mother', 276),
#  ('open', 276),
#  ('buy', 275),
#  ('water', 274),
#  ('wild', 273),
#  ('makes', 273),
#  ('saw', 272),
#  ('feels', 270),
#  ('lets', 268),
#  ('says', 265),
#  ('x', 265),
#  ('drink', 264),
#  ('sex', 264),
#  ('doing', 263),
#  ('million', 262),
#  ('verse', 261),
#  ('today', 261),
#  ('listen', 260),
#  ('gold', 260),
#  ('air', 259),
#  ('n', 258),
#  ('meet', 258),
#  ('yet', 258),
#  ('word', 257),
#  ('lady', 257),
#  ('wonder', 257),
#  ('else', 256),
#  ('set', 255),
#  ('ha', 254),
#  ('found', 253),
#  ('fast', 253),
#  ('nah', 253),
#  ('saying', 252),
#  ('broken', 251),
#  ('very', 251),
#  ('act', 250),
#  ('king', 248),
#  ('nothin', 248),
#  ('pop', 247),
#  ('cool', 246),
#  ('kill', 246),
#  ('tried', 245),
#  ('tryin', 244),
#  ('such', 244),
#  ('street', 243),
#  ('swear', 243),
#  ('star', 241),
#  ('met', 241),
#  ('lil', 241),
#  ('tryna', 241),
#  ('comin', 237),
#  ('moon', 237),
#  ('eh', 237),
#  ('ho', 237),
#  ('loving', 237),
#  ('wanted', 237),
#  ('mouth', 236),
#  ('tight', 235),
#  ('mad', 235),
#  ('summer', 235),
#  ('upon', 235),
#  ('blood', 234),
#  ('pray', 234),
#  ('hood', 234),
#  ('sea', 232),
#  ('both', 232),
#  ('thinking', 232),
#  ('gun', 231),
#  ('past', 231),
#  ('tears', 231),
#  ('rap', 231),
#  ('youre', 231),
#  ('kids', 230),
#  ('smoke', 230),
#  ('motherfucker', 230),
#  ('between', 229),
#  ('dog', 229),
#  ('flow', 229),
#  ('shine', 228),
#  ('started', 228),
#  ('nixgaz', 226),
#  ('child', 225),
#  ('chance', 225),
#  ('wake', 225),
#  ('motherfuckers', 225),
#  ('kind', 224),
#  ('soon', 224),
#  ('use', 224),
#  ('eye', 224),
#  ('broke', 224),
#  ('boom', 224),
#  ('shall', 221),
#  ('clothes', 221),
#  ('pass', 221),
#  ('school', 221),
#  ('fool', 220),
#  ('strong', 220),
#  ('children', 219),
#  ('death', 219),
#  ('half', 219),
#  ('doin', 219),
#  ('ground', 218),
#  ('pick', 218),
#  ('fine', 218),
#  ('power', 218),
#  ('feelin', 218),
#  ('control', 218),
#  ('felt', 217),
#  ('bag', 216),
#  ('drive', 215),
#  ('whatever', 215),
#  ('women', 214),
#  ('being', 213),
#  ('year', 213),
#  ('somethin', 212),
#  ('chick', 212),
#  ('sit', 211),
#  ('push', 211),
#  ('reason', 210),
#  ('truth', 210),
#  ('bright', 210),
#  ('seems', 210),
#  ('brother', 209),
#  ('sorry', 209),
#  ('wall', 208),
#  ('front', 208),
#  ('rest', 207),
#  ('save', 205),
#  ('read', 205),
#  ('making', 205),
#  ('c', 205),
#  ('lover', 204),
#  ('standing', 203),
#  ('bought', 203),
#  ('funk', 203),
#  ('step', 202),
#  ('mma', 202),
#  ('fun', 201),
#  ('along', 200),
#  ('wind', 200),
#  ('number', 200),
#  ('couldn', 199),
#  ('sound', 199),
#  ('green', 198),
#  ('mr', 198),
#  ('taking', 197),
#  ('wants', 196),
#  ('tomorrow', 195),
#  ('burn', 195),
#  ('wont', 193),
#  ('part', 193),
#  ('four', 193),
#  ('ay', 193),
#  ('perfect', 192),
#  ('gets', 191),
#  ('window', 190),
#  ('rich', 190),
#  ('ice', 189),
#  ('b', 189),
#  ('already', 189),
#  ('sick', 189),
#  ('caught', 188),
#  ('does', 188),
#  ('stars', 188),
#  ('g', 188),
#  ('loved', 185),
#  ('catch', 185),
#  ('send', 185),
#  ('most', 185),
#  ('whats', 185),
#  ('men', 184),
#  ('jesus', 184),
#  ('train', 184),
#  ('different', 184),
#  ('father', 184),
#  ('jack', 184),
#  ('called', 183),
#  ('block', 183),
#  ('five', 183),
#  ('fell', 182),
#  ('hundred', 182),
#  ('sayin', 181),
#  ('running', 181),
#  ('apart', 181),
#  ('loves', 181),
#  ('earth', 180),
#  ('son', 180),
#  ('family', 179),
#  ('seem', 178),
#  ('hello', 178),
#  ('win', 178),
#  ('grab', 178),
#  ('lies', 177),
#  ('bit', 177),
#  ('thank', 177),
#  ('keys', 177),
#  ('cash', 177),
#  ('bet', 176),
#  ('tired', 175),
#  ('darling', 175),
#  ('promise', 175),
#  ('ladies', 175),
#  ('trust', 175),
#  ('moment', 174),
#  ('rise', 174),
#  ('fear', 173),
#  ('land', 172),
#  ('follow', 172),
#  ('doesn', 171),
#  ('okay', 170),
#  ('bone', 170),
#  ('lips', 170),
#  ('story', 169),
#  ('ring', 168),
#  ('war', 168),
#  ('bust', 168),
#  ('nice', 167),
#  ('shut', 167),
#  ('above', 166),
#  ('style', 166),
#  ('voice', 166),
#  ('which', 165),
#  ('de', 165),
#  ('brain', 164),
#  ('stupid', 164),
#  ('river', 164),
#  ('imma', 164),
#  ('holy', 163),
#  ('yea', 162),
#  ('wouldn', 162),
#  ('dirty', 162),
#  ('space', 162),
#  ('everyone', 162),
#  ('woo', 162),
#  ('scream', 161),
#  ('speak', 160),
#  ('wear', 159),
#  ('cuz', 159),
#  ('sexy', 159),
#  ('thousand', 158),
#  ('worry', 158),
#  ('across', 157),
#  ('against', 157),
#  ('diamonds', 157),
#  ('spit', 157),
#  ('takes', 156),
#  ('ball', 156),
#  ('calling', 155),
#  ('freak', 155),
#  ('blame', 155),
#  ('afraid', 155),
#  ('brown', 155),
#  ('yours', 155),
#  ('york', 155),
#  ('prayer', 155),
#  ('missy', 155),
#  ('shoot', 154),
#  ('born', 154),
#  ('cannot', 154),
#  ('six', 154),
#  ('walking', 153),
#  ('sign', 152),
#  ('taste', 152),
#  ('ok', 152),
#  ('diamond', 152),
#  ('couple', 152),
#  ('everywhere', 151),
#  ('skin', 151),
#  ('laugh', 150),
#  ('paper', 150),
#  ('ten', 148),
#  ('died', 148),
#  ('future', 148),
#  ('cars', 148),
#  ('turned', 147),
#  ('ones', 147),
#  ('joy', 147),
#  ('shoes', 147),
#  ('tree', 146),
#  ('spend', 146),
#  ('almost', 146),
#  ('fresh', 146),
#  ('outta', 145),
#  ('minute', 145),
#  ('runnin', 145),
#  ('looks', 145),
#  ('livin', 145),
#  ('twenty', 145),
#  ('higher', 144),
#  ('great', 144),
#  ('second', 144),
#  ('michael', 144),
#  ('queen', 143),
#  ('lovin', 143),
#  ('hide', 143),
#  ('drunk', 143),
#  ('lift', 143),
#  ('meant', 142),
#  ('r', 142),
#  ('makin', 141),
#  ('stick', 141),
#  ('write', 141),
#  ('reach', 141),
#  ('learn', 141),
#  ('picture', 139),
#  ('looked', 139),
#  ('breath', 139),
#  ('outside', 138),
#  ('breathe', 138),
#  ('weed', 138),
#  ('welcome', 138),
#  ('crack', 138),
#  ('key', 137),
#  ('momma', 137),
#  ('ran', 137),
#  ('business', 136),
#  ('least', 136),
#  ('probably', 136),
#  ('bang', 136),
#  ('somewhere', 135),
#  ('wings', 135),
#  ('piece', 135),
#  ('fill', 135),
#  ('hoe', 135),
#  ('kick', 135),
#  ('yah', 135),
#  ('human', 134),
#  ('keeps', 134),
#  ('e', 134),
#  ('stone', 133),
#  ('singing', 133),
#  ('sad', 133),
#  ('scared', 133),
#  ('few', 133),
#  ('treat', 132),
#  ('ye', 132),
#  ('p', 132),
#  ('bridge', 131),
#  ('kinda', 131),
#  ('jump', 131),
#  ('dancing', 131),
#  ('hang', 131),
#  ('reasons', 131),
#  ('favorite', 131),
#  ('grind', 131),
#  ('homie', 131),
#  ('thinkin', 130),
#  ('nights', 130),
#  ('dj', 130),
#  ('goodbye', 129),
#  ('cross', 129),
#  ('mirror', 129),
#  ('brand', 129),
#  ('playing', 128),
#  ('track', 128),
#  ('west', 128),
#  ('guy', 128),
#  ('kanye', 128),
#  ('devil', 127),
#  ('paid', 127),
#  ('fake', 127),
#  ('fame', 127),
#  ('wayne', 127),
#  ('yellow', 126),
#  ('cup', 126),
#  ('cat', 126),
#  ('callin', 126),
#  ('dear', 126),
#  ('crying', 126),
#  ('wasn', 126),
#  ('anybody', 126),
#  ('carry', 125),
#  ('giving', 125),
#  ('magic', 125),
#  ('peace', 125),
#  ('asked', 125),
#  ('birthday', 125),
#  ('fucked', 125),
#  ('dress', 124),
#  ('knees', 124),
#  ('hee', 124),
#  ('falling', 123),
#  ('everyday', 123),
#  ('anymore', 123),
#  ('fat', 123),
#  ('spot', 123),
#  ('mon', 123),
#  ('funny', 122),
#  ('wife', 122),
#  ('means', 122),
#  ('supposed', 122),
#  ('l', 122),
#  ('benz', 122),
#  ('telling', 121),
#  ('worth', 121),
#  ('yeezy', 121),
#  ('burning', 120),
#  ('near', 120),
#  ('shout', 120),
#  ('hour', 119),
#  ('clear', 119),
#  ('warm', 119),
#  ('strange', 119),
#  ('quick', 119),
#  ('miles', 118),
#  ('songs', 118),
#  ('nowhere', 118),
#  ('changes', 118),
#  ('known', 118),
#  ('booty', 118),
#  ('seven', 118),
#  ('mess', 117),
#  ('played', 117),
#  ('answer', 117),
#  ('rather', 117),
#  ('takin', 117),
#  ('needs', 117),
#  ('naked', 117),
#  ('workin', 117),
#  ('bobby', 117),
#  ('knock', 117),
#  ('monster', 117),
#  ('bum', 117),
#  ('park', 116),
#  ('uhh', 116),
#  ('yesterday', 115),
#  ('small', 115),
#  ('bird', 115),
#  ('sell', 115),
#  ('weak', 115),
#  ('watching', 115),
#  ('jeans', 115),
#  ('tear', 114),
#  ('middle', 114),
#  ('empty', 114),
#  ('faith', 114),
#  ('glad', 114),
#  ('mary', 113),
#  ('wet', 113),
#  ('angel', 112),
#  ('ways', 112),
#  ('box', 112),
#  ('clouds', 112),
#  ('teeth', 112),
#  ('point', 111),
#  ('mi', 111),
#  ('chain', 110),
#  ('finally', 110),
#  ('mommy', 110),
#  ('walked', 110),
#  ('job', 110),
#  ('stuck', 110),
#  ('cake', 109),
#  ('motherfuckin', 109),
#  ('boss', 108),
#  ('doo', 108),
#  ('movie', 108),
#  ('plus', 108),
#  ('team', 108),
#  ('type', 108),
#  ('rolling', 107),
#  ('sight', 107),
#  ('shady', 107),
#  ('wine', 106),
#  ('sister', 106),
#  ('bottom', 106),
#  ('cried', 106),
#  ('clean', 106),
#  ('sorrow', 106),
#  ('soft', 106),
#  ('needed', 106),
#  ('lit', 106),
#  ('hop', 106),
#  ('fingers', 105),
#  ('news', 105),
#  ('grow', 105),
#  ('quit', 105),
#  ('leaving', 105),
#  ('return', 105),
#  ('kid', 105),
#  ('tongue', 105),
#  ('shots', 105),
#  ('blind', 104),
#  ('bar', 104),
#  ('vibe', 104),
#  ('brought', 103),
#  ('secret', 103),
#  ('handle', 103),
#  ('changed', 103),
#  ('radio', 103),
#  ('christmas', 103),
#  ('deal', 103),
#  ('thee', 103),
#  ('icky', 103),
#  ('none', 102),
#  ('south', 102),
#  ('country', 102),
#  ('single', 102),
#  ('longer', 102),
#  ('grown', 102),
#  ('mo', 102),
#  ('unless', 102),
#  ('haters', 102),
#  ('birds', 101),
#  ('heat', 101),
#  ('chest', 101),
#  ('table', 101),
#  ('lead', 100),
#  ('hook', 100),
#  ('realize', 100),
#  ('band', 100),
#  ('race', 100),
#  ('hearts', 100),
#  ('daughter', 100),
#  ('f', 100),
#  ('dope', 100),
#  ('hoo', 100),
#  ('ahead', 99),
#  ('fact', 99),
#  ('holding', 99),
#  ('dry', 99),
#  ('stuff', 99),
#  ('fix', 99),
#  ('spirit', 99),
#  ('weezy', 99),
#  ('scene', 98),
#  ('guns', 98),
#  ('bye', 98),
#  ('price', 98),
#  ('later', 98),
#  ('fish', 98),
#  ('mom', 98),
#  ('suck', 98),
#  ('shining', 97),
#  ('poor', 97),
#  ('hallelujah', 97),
#  ('ta', 97),
#  ('lives', 96),
#  ('playin', 96),
#  ('chains', 96),
#  ('hours', 96),
#  ...]

# %% [markdown]
# ### 정렬하고 출력해봤더니 단어장의 중요도와 순서는 단어의 개수로 판단하는것을 알수 있었다.

# %% [markdown]
# # 5. 소스 문장 생성
#
# ### 문장의 제일 뒤에 있는 단어와 앞에 있는 단어를 제거해 소스 문장을 생성한다.

# %%
# tensor에서 마지막 토큰을 잘라내서 소스 문장을 생성합니다
# 마지막 토큰은 <end>가 아니라 <pad>일 가능성이 높습니다.
src_input = tensor[:, :-1]  
# tensor에서 <start>를 잘라내서 타겟 문장을 생성합니다.
tgt_input = tensor[:, 1:]    

print(src_input[0])
print(tgt_input[0])
# Out:
# [  2  62 271  27  94 546  20  86 743  90   3   0   0   0]
# [ 62 271  27  94 546  20  86 743  90   3   0   0   0   0]

# %% [markdown]
# # 6. 데이터 분류
#
# ### 학습과 테스트를 위해 4:1 비율로 트레이닝셋과 테스트셋을 분리한다.

# %%
enc_train, enc_val, dec_train, dec_val = train_test_split(src_input, tgt_input, test_size=0.2, random_state=5)

# %%
print("Source Train:", enc_train.shape)
print("Target Train:", dec_train.shape)
# Out:
# Source Train: (124939, 14)
# Target Train: (124939, 14)

# %% [markdown]
# ### 예제에 있는 단어보다 적게 나왔다.
#
# ### 이유는 정제된 문장이 단어가 0개인 경우가 있었는데 이 경우를 순서를 바꿔 정제 후 단어가 0개인 문장을 제거하니 더 적게 나왔다.

# %% [markdown]
# # 7. 버퍼사이즈와 배치사이즈를 정합니다.
#
# ### 검색을 하다 보니 배치사이즈와 에폭이 같이 나오는 경우가 많아 같이 검색해서 아래의 블로그를 참고했습니다.<br/>https://m.blog.naver.com/qbxlvnf11/221449297033

# %%
BUFFER_SIZE = len(src_input)
BATCH_SIZE = 256
steps_per_epoch = len(src_input) // BATCH_SIZE

 # tokenizer가 구축한 단어사전 내 12000개와, 여기 포함되지 않은 0:<pad>를 포함하여 12001개
VOCAB_SIZE = tokenizer.num_words + 1   

# 준비한 데이터 소스로부터 데이터셋을 만듭니다
# 데이터셋에 대해서는 아래 문서를 참고하세요
# 자세히 알아둘수록 도움이 많이 되는 중요한 문서입니다
# https://www.tensorflow.org/api_docs/python/tf/data/Dataset
dataset = tf.data.Dataset.from_tensor_slices((src_input, tgt_input))
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
dataset
# Out:
# <BatchDataset shapes: ((256, 14), (256, 14)), types: (tf.int32, tf.int32)>

# %% [markdown]
# # 8. 모델 설계
#
# ### 저번 익스와 다르게 함수형인것을 TF 마스터 수업에서 조원의 도움으로 알게 되어 아래 블로그를 참고했습니다.<br/>https://www.tensorflow.org/guide/keras/functional?hl=ko

# %%
class TextGenerator(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, hidden_size):
        super().__init__()
        
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.rnn_1 = tf.keras.layers.LSTM(hidden_size, return_sequences=True)
        self.rnn_2 = tf.keras.layers.LSTM(hidden_size, return_sequences=True)
        self.linear = tf.keras.layers.Dense(vocab_size)
        
    def call(self, x):
        out = self.embedding(x)
        out = self.rnn_1(out)
        out = self.rnn_2(out)
        out = self.linear(out)
        
        return out
    
embedding_size = 512
hidden_size = 2048
model = TextGenerator(tokenizer.num_words + 1, embedding_size , hidden_size)

# %%
# 데이터셋에서 데이터 한 배치만 불러오는 방법입니다.
# 지금은 동작 원리에 너무 빠져들지 마세요~
for src_sample, tgt_sample in dataset.take(1): break

# 한 배치만 불러온 데이터를 모델에 넣어봅니다
model(src_sample)
# Out:
# <tf.Tensor: shape=(256, 14, 12001), dtype=float32, numpy=
# array([[[ 1.24512342e-04,  5.83188485e-05, -1.61438948e-05, ...,
#           1.38139090e-04,  3.00310512e-05, -1.84129050e-04],
#         [ 5.46288735e-04,  1.03350227e-04,  3.64425272e-04, ...,
#           2.15088381e-04, -4.69709230e-05, -2.62921996e-04],
#         [ 1.19165110e-03,  5.69949625e-04,  3.74548894e-04, ...,
#           2.98361963e-04,  2.57919019e-04, -8.58039930e-05],
#         ...,
#         [ 1.77767430e-03,  3.20719410e-04, -1.61111145e-03, ...,
#           2.25838786e-03,  1.84631845e-05,  1.15446041e-04],
#         [ 1.67242880e-03,  7.27213221e-04, -2.20229500e-03, ...,
#           2.65908451e-03, -4.29614156e-05, -3.32463009e-04],
#         [ 1.58718706e-03,  1.12879463e-03, -2.82804877e-03, ...,
#           3.01699201e-03, -6.26632973e-05, -8.78968916e-04]],
#
#        [[ 1.24512342e-04,  5.83188485e-05, -1.61438948e-05, ...,
#           1.38139090e-04,  3.00310512e-05, -1.84129050e-04],
#         [ 1.27307067e-04,  1.12269969e-04, -2.12032173e-04, ...,
#          -2.50324138e-05,  2.67426192e-04,  2.25439071e-04],
#         [ 2.23244897e-05, -2.59466178e-04, -2.78879743e-04, ...,
#          -4.39389347e-04,  4.36470320e-04,  5.85100614e-04],
#         ...,
#         [-1.47812447e-04, -8.38979788e-04, -2.56678951e-03, ...,
#           1.80105085e-03,  1.23251029e-05, -1.43569626e-03],
#         [ 1.53130004e-05, -3.14789882e-04, -3.19257309e-03, ...,
#           2.37711333e-03,  8.87782226e-05, -2.08219863e-03],
#         [ 1.61115546e-04,  1.89468148e-04, -3.80096678e-03, ...,
#           2.89113517e-03,  1.84998891e-04, -2.69663101e-03]],
#
#        [[ 1.24512342e-04,  5.83188485e-05, -1.61438948e-05, ...,
#           1.38139090e-04,  3.00310512e-05, -1.84129050e-04],
#         [ 2.40682653e-04,  2.62513408e-04,  1.77630591e-05, ...,
#           2.30038815e-04, -1.70192579e-04, -1.84128003e-04],
#         [ 3.34820681e-04,  1.45569371e-04, -3.85337422e-04, ...,
#           1.12132053e-04, -1.08020402e-04, -3.34490149e-04],
#         ...,
#         [ 4.30328277e-04,  9.87646054e-04, -4.13881661e-03, ...,
#           2.78187450e-03,  3.10424366e-04, -2.33927695e-03],
#         [ 5.49647666e-04,  1.37739163e-03, -4.63378290e-03, ...,
#           3.27431969e-03,  3.82806960e-04, -2.97455094e-03],
#         [ 6.54138043e-04,  1.71927165e-03, -5.06838597e-03, ...,
#           3.70103610e-03,  4.64712444e-04, -3.56596196e-03]],
#
#        ...,
#
#        [[ 1.24512342e-04,  5.83188485e-05, -1.61438948e-05, ...,
#           1.38139090e-04,  3.00310512e-05, -1.84129050e-04],
#         [ 9.09179726e-05,  1.89726372e-04, -4.51797423e-05, ...,
#          -1.10571869e-04,  6.10334566e-04, -3.46027547e-04],
#         [-3.57422221e-04,  1.49318614e-04,  1.57041577e-04, ...,
#          -4.76472196e-04,  4.35284048e-04, -5.56757324e-04],
#         ...,
#         [-8.34220846e-04,  2.28877435e-03, -3.48571292e-03, ...,
#           8.99788924e-04, -5.69029507e-05, -7.79382535e-04],
#         [-5.45907184e-04,  2.56960792e-03, -4.09300579e-03, ...,
#           1.58893794e-03, -7.76467186e-06, -1.30473496e-03],
#         [-2.77008512e-04,  2.81201722e-03, -4.65655467e-03, ...,
#           2.20691925e-03,  5.46555784e-05, -1.87979848e-03]],
#
#        [[ 1.24512342e-04,  5.83188485e-05, -1.61438948e-05, ...,
#           1.38139090e-04,  3.00310512e-05, -1.84129050e-04],
#         [ 8.40334469e-05, -5.26235905e-04, -1.07530264e-04, ...,
#           2.18385452e-04, -2.15130804e-05, -8.27631215e-04],
#         [ 9.08691654e-05, -1.05398579e-03, -1.28517378e-04, ...,
#           3.76004318e-04, -2.51800724e-04, -1.42299093e-03],
#         ...,
#         [ 9.50116519e-05, -9.24980675e-04, -1.45647419e-03, ...,
#          -2.26480974e-04, -7.21845543e-04, -8.41183239e-04],
#         [ 4.62151547e-05, -3.98999924e-04, -1.73581659e-03, ...,
#           4.28812316e-04, -5.66998322e-04, -8.35106010e-04],
#         [ 9.72940834e-05,  8.64014146e-05, -2.12167110e-03, ...,
#           1.06856693e-03, -4.69104736e-04, -1.05876604e-03]],
#
#        [[ 1.24512342e-04,  5.83188485e-05, -1.61438948e-05, ...,
#           1.38139090e-04,  3.00310512e-05, -1.84129050e-04],
#         [ 3.67470697e-04,  4.56637237e-04,  1.63636316e-04, ...,
#           3.30251612e-04,  1.45820013e-04, -5.58313157e-04],
#         [ 3.63660656e-04,  2.56163738e-04,  2.70314165e-04, ...,
#          -4.36322216e-06,  2.65134353e-04, -5.68037154e-04],
#         ...,
#         [ 9.59426980e-04,  2.12221872e-03,  1.79758319e-03, ...,
#          -1.64409133e-03,  2.06395076e-03, -1.06034894e-03],
#         [ 4.65955411e-04,  2.29793345e-03,  1.15236838e-03, ...,
#          -1.29856018e-03,  1.97159429e-03, -5.91163815e-04],
#         [ 2.31336890e-04,  2.37012818e-03,  4.22331679e-04, ...,
#          -7.19689822e-04,  1.68124214e-03, -3.94008617e-04]]],
#       dtype=float32)>

# %%
model.summary()
# Out:
# Model: "text_generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        multiple                  6144512
# _________________________________________________________________
# lstm (LSTM)                  multiple                  20979712
# _________________________________________________________________
# lstm_1 (LSTM)                multiple                  33562624
# _________________________________________________________________
# dense (Dense)                multiple                  24590049
# =================================================================
# Total params: 85,276,897
# Trainable params: 85,276,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer와 loss등은 차차 배웁니다
# 혹시 미리 알고 싶다면 아래 문서를 참고하세요
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
# https://www.tensorflow.org/api_docs/python/tf/keras/losses
# 양이 상당히 많은 편이니 지금 보는 것은 추천하지 않습니다
optimizer = tf.keras.optimizers.Adam()
loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True,
    reduction='none'
)

model.compile(loss=loss, optimizer=optimizer)
model.fit(enc_train, dec_train, epochs=4, validation_data=(enc_val, dec_val))
# Out:
# Epoch 1/4
# 3905/3905 [==============================] - 930s 238ms/step - loss: 3.2139 - val_loss: 2.6266
# Epoch 2/4
# 3905/3905 [==============================] - 929s 238ms/step - loss: 2.4055 - val_loss: 2.3763
# Epoch 3/4
# 3905/3905 [==============================] - 929s 238ms/step - loss: 1.9107 - val_loss: 2.2413
# Epoch 4/4
# 3905/3905 [==============================] - 928s 238ms/step - loss: 1.5424 - val_loss: 2.1982

# %% [markdown]
# # epoch 5
#
# embedding_size = 128
# <br/>hidden_size = 1024
# <br/>loss: 1.9839 - val_loss: 2.4296
#
# embedding_size = 256
# <br/>hidden_size = 1024
# <br/>loss: 1.9083 - val_loss: 2.3947
#
# embedding_size = 512
# <br/>hidden_size = 1024
# <br/>loss: 1.8408 - val_loss: 2.3680
#
# embedding_size = 1024
# <br/>hidden_size = 1024
# <br/>loss: 1.8163 - val_loss: 2.3648
#
# embedding_size = 256
# <br/>hidden_size = 2048
# <br/>loss: 1.3801 - val_loss: 2.2346
#
# embedding_size = 512
# <br/>hidden_size = 2048
# <br/>loss: 1.3033 - val_loss: 2.2164
#
# embedding_size = 1024
# <br/>hidden_size = 2048
# <br/>loss: loss: 1.2835 - val_loss: 2.2091
#
# # epoch 4
#
# embedding_size = 256
# <br/>hidden_size = 2048
# <br/>loss: 1.5385 - val_loss: 2.1943

# %% [markdown]
# ### val_loss값을 2.2 이하로 낮추기 위해 처음엔 embedding_size와 hidden_size만 바꿔가며 학습하다 hidden_size가 커지면 오버피팅이 일어나서 epoch을 낮춰 2.2이하의 val_loss값을 구했습니다.

# %%
def generate_text(model, tokenizer, init_sentence="<start>", max_len=20):
    # 테스트를 위해서 입력받은 init_sentence도 텐서로 변환합니다
    test_input = tokenizer.texts_to_sequences([init_sentence])
    test_tensor = tf.convert_to_tensor(test_input, dtype=tf.int64)
    end_token = tokenizer.word_index["<end>"]

    # 단어 하나씩 예측해 문장을 만듭니다
    #    1. 입력받은 문장의 텐서를 입력합니다
    #    2. 예측된 값 중 가장 높은 확률인 word index를 뽑아냅니다
    #    3. 2에서 예측된 word index를 문장 뒤에 붙입니다
    #    4. 모델이 <end>를 예측했거나, max_len에 도달했다면 문장 생성을 마칩니다
    while True:
        # 1
        predict = model(test_tensor) 
        # 2
        predict_word = tf.argmax(tf.nn.softmax(predict, axis=-1), axis=-1)[:, -1] 
        # 3 
        test_tensor = tf.concat([test_tensor, tf.expand_dims(predict_word, axis=0)], axis=-1)
        # 4
        if predict_word.numpy()[0] == end_token: break
        if test_tensor.shape[1] >= max_len: break

    generated = ""
    # tokenizer를 이용해 word index를 단어로 하나씩 변환합니다 
    for word_index in test_tensor[0].numpy():
        generated += tokenizer.index_word[word_index] + " "

    return generated

# %% [markdown]
# # 9. 문장을 만들어 보았습니다.

# %%
generate_text(model, tokenizer, init_sentence="<start> i love", max_len=20)
# Out:
# '<start> i love ma little nasty girl <end> '

# %% [markdown]
# ### 완전한 문장은 아니지만 어느정도 의미는 알것 같습니다.

# %% [markdown]
# # 회고
#
# ### 임베딩 사이즈와 히든 사이즈를 바꿔가며 학습속도가 엄청나게 달라지는것을 구글링과 직접 몸으로 느낄수 있었습니다.
#
# ### 하이퍼 파라미터의 중요도를 알수 있었다고 생각하고, 학습속도가 느리더라도 테스트속도와 loss값만 낮다면 좋다고 생각하지만 테스트 속도만 낮추는 방법은 좀더 고민해 봐야 할것 같습니다.
